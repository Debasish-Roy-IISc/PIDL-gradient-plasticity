# %% [markdown]
# # Imports

# %%
import pickle
import time
from pathlib import Path

import jax
import numpy as np
import optax
import pandas as pd
from flax import linen as nn
from flax import serialization
from flax.training import train_state
from jax import numpy as jnp
from jax import random
from matplotlib import cm
from matplotlib import pyplot as plt

# %% [markdown]
# # Helpers

# %%
class MLP(nn.Module):
    widths: list[int]

    @nn.compact
    def __call__(self, x):
        for i, w in enumerate(self.widths):
            x = nn.Dense(w)(x)
            if i != len(self.widths) - 1:
                x = nn.tanh(x)
        return x

# %% [markdown]
# # Parameters

# %%
xmin = 0.0
xmax = 10.0

tmin = 0.0
tmax = 0.5
umax = 1.0

# %%
S0 = 100.0
d0 = 0.1
m = 0.02

# %% [markdown]
# # Scaling

# %%
# Don't change `L` and `T`.
# BC inforcement in the model, assumes them as given below,
# e.g. it is assumed that x0 = t0 = 0 and x1 = t1 = 1.
L = xmax - xmin
T = tmax - tmin
U = umax
Γ = U / L
μscale = 100e3

# %%
x0 = xmin / L
x1 = xmax / L
t0 = tmin / T
t1 = tmax / T

# %% [markdown]
# # Seed

# %%
key = random.key(0)
# Out:
# 2024-08-12 16:24:19.775378: W external/xla/xla/service/gpu/nvptx_compiler.cc:765] The NVIDIA driver's CUDA version is 12.4 which is older than the ptxas CUDA version (12.5.82). Because the driver is older than the ptxas version, XLA is disabling parallel compilation, which may slow down compilation. You should update your NVIDIA driver or use the NVIDIA-provided CUDA forward compatibility packages.

# %% [markdown]
# # Model

# %%
class Module(nn.Module):
    hidden_width: int
    num_hidden_layers: int

    @nn.compact
    def __call__(self, X):
        widths = [self.hidden_width] * self.num_hidden_layers + [2]
        u, γp = MLP(widths)(X)

        t, x = X[:2]
        u = t * x * (1 - x) * u + t * x * umax / U
        γp *= t

        return u, γp

# %%
module = Module(64, 3)

# %% [markdown]
# # Loss function

# %%
def loss_fn(params, state, X):
    def loss_per_sample(x):
        μ = x[2] * μscale
        _, γp = state.apply_fn({"params": params}, x)
        γp *= Γ
        du_fn = jax.grad(lambda x: state.apply_fn({"params": params}, x)[0])
        du_dx = du_fn(x)[1] * U / L
        d2u_dx2 = jax.grad(lambda x: du_fn(x)[1])(x)[1] * U / L**2
        dγp = jax.grad(lambda x: state.apply_fn({"params": params}, x)[1])(x)
        γpdot, dγp_dx = dγp[0] * Γ / T, dγp[1] * Γ / L

        dp = jnp.abs(γpdot)

        macro_loss = μ * (d2u_dx2 - dγp_dx) / S0
        micro_loss = (μ * (du_dx - γp) - S0 * (dp / d0) ** m * jnp.sign(γpdot)) / S0

        return macro_loss**2 + micro_loss**2

    return jnp.mean(jax.vmap(loss_per_sample)(X))

# %% [markdown]
# # Training points

# %%
# Grid points
# Avoid boundaries by a small margin
ε = 1e-7

μ0 = 10e3 / μscale
μ1 = 1000e3 / μscale

nx = 30
nt = 100
nμ = 30

xs = jnp.linspace(x0+ε, x1-ε, nx)
ts = jnp.linspace(t0+ε, t1-ε, nt)
μs = jnp.linspace(μ0, μ1, nμ)
tgrid, xgrid, μgrid = jnp.meshgrid(ts, xs, μs)
X_train = jnp.column_stack([tgrid.flatten(), xgrid.flatten(), μgrid.flatten()])

μs
# Out:
# Array([ 0.1       ,  0.4413793 ,  0.78275865,  1.1241379 ,  1.4655173 ,
#         1.8068967 ,  2.1482759 ,  2.4896553 ,  2.8310344 ,  3.1724138 ,
#         3.5137932 ,  3.8551724 ,  4.1965513 ,  4.537931  ,  4.87931   ,
#         5.22069   ,  5.562069  ,  5.9034486 ,  6.2448277 ,  6.5862074 ,
#         6.9275866 ,  7.2689652 ,  7.610345  ,  7.951724  ,  8.293103  ,
#         8.634482  ,  8.975862  ,  9.317242  ,  9.658621  , 10.        ],      dtype=float32)

# %% [markdown]
# # Optimizer

# %%
epochs = 100
batch_size = 256
steps = epochs * len(X_train) // batch_size
steps
# Out:
# 35156

# %%
lr = optax.linear_schedule(1e-2, 1e-5, steps)
tx = optax.adam(lr)

# %% [markdown]
# # Training state

# %%
class TrainState(train_state.TrainState):
    loss: float


def create_train_state(module, key, tx):
    params = module.init(key, jnp.ones(3))["params"]
    return TrainState.create(apply_fn=module.apply, params=params, tx=tx, loss=None)

# %%
key, subkey = random.split(key)
state = create_train_state(module, subkey, tx)

# %% [markdown]
# # Train step

# %%
@jax.jit
def train_step(state, X):
    loss, grads = jax.value_and_grad(loss_fn)(state.params, state, X)
    state = state.apply_gradients(grads=grads)
    state = state.replace(loss=loss)
    return state

# %% [markdown]
# # Training

# %%
print_every = 1000
loss_history = []

# %%
def dataloader(arrays, batch_size):
    dataset_size = arrays[0].shape[0]
    assert all(array.shape[0] == dataset_size for array in arrays)
    indices = np.arange(dataset_size)
    while True:
        perm = np.random.permutation(indices)
        start = 0
        end = batch_size
        while end <= dataset_size:
            batch_perm = perm[start:end]
            yield tuple(array[batch_perm] for array in arrays)
            start = end
            end = start + batch_size

iter_data = dataloader((X_train,), batch_size)

# %%
start_time = time.time()
for step, (x,) in zip(range(steps), iter_data):
    state = train_step(state, x)
    loss_history.append(state.loss.item())
    if (step % print_every == 0) or (step == steps - 1):
        print(
            f"{step=}, train_loss={loss_history[-1]}"
        )
print(f"Training over! Time taken {time.time() - start_time} s.")
# Out:
# step=0, train_loss=316084.78125
# step=1000, train_loss=0.2012680470943451
# step=2000, train_loss=0.13413040339946747
# step=3000, train_loss=0.12648002803325653
# step=4000, train_loss=1.3497707843780518
# step=5000, train_loss=0.2316274493932724
# step=6000, train_loss=0.3745076358318329
# step=7000, train_loss=30.906442642211914
# step=8000, train_loss=1532.7132568359375
# step=9000, train_loss=0.0997174084186554
# step=10000, train_loss=0.6117815375328064
# step=11000, train_loss=0.057930056005716324
# step=12000, train_loss=0.2050490528345108
# step=13000, train_loss=0.5482594966888428
# step=14000, train_loss=0.03815022483468056
# step=15000, train_loss=6.811061859130859
# step=16000, train_loss=0.10036997497081757
# step=17000, train_loss=0.603236734867096
# step=18000, train_loss=0.05706221982836723
# step=19000, train_loss=0.0344286784529686
# step=20000, train_loss=0.03427337110042572
# step=21000, train_loss=0.3292561173439026
# step=22000, train_loss=4.504449844360352
# step=23000, train_loss=0.03577670454978943
# step=24000, train_loss=0.014061469584703445
# step=25000, train_loss=0.01613745279610157
# step=26000, train_loss=44.74462890625
# step=27000, train_loss=0.009748905897140503
# step=28000, train_loss=0.012642104178667068
# step=29000, train_loss=0.020482249557971954
# step=30000, train_loss=0.013004262000322342
# step=31000, train_loss=0.017434462904930115
# step=32000, train_loss=0.01842145062983036
# step=33000, train_loss=0.03871937841176987
# step=34000, train_loss=0.012072743847966194
# step=35000, train_loss=0.011920038610696793
# step=35155, train_loss=0.012216087430715561
# Training over! Time taken 45.70077967643738 s.

# %%
save_dir = Path("/home/ankit/OneDrive/PINN_Lele/flax_scripts3/src/notebooks/saved_models/")
with open(save_dir / "params_mu_extrapolation.pickle", "wb") as f:
    pickle.dump(serialization.to_state_dict(state.params), f)

# %%
plt.plot(loss_history)
plt.xlabel("Steps")
plt.ylabel("Loss")
plt.yscale("log")
plt.show()

# %% [markdown]
# # Testing

# %%
# Load the trained module
model_path = "/home/ankit/OneDrive/PINN_Lele/flax_scripts3/src/notebooks/saved_models/params_mu_extrapolation.pickle"
with open(model_path, "rb") as f:
    trained_dict = pickle.load(f)
key, subkey = random.split(key)
params = module.init(subkey, jnp.ones(3))["params"]
params = serialization.from_state_dict(params, trained_dict)
state = state.replace(params=params)

# %%
μ = 100e3
n = 100

ts = jnp.linspace(t0, t1, n)
xs = jnp.linspace(x0, x1, n)
tgrid, xgrid = jnp.meshgrid(ts, xs)
tvec = tgrid.flatten()
xvec = xgrid.flatten()
X_test = jnp.column_stack([tvec, xvec, jnp.full_like(tvec, μ / μscale)])

# %%
u, γp = jax.vmap(lambda x: state.apply_fn({"params": state.params}, x))(X_test)
u *= U
γp *= Γ

du = jax.vmap(jax.grad(lambda x: state.apply_fn({"params": state.params}, x)[0]))(X_test)
du_dx = du[:, 1] * U / L
τ = μ * (du_dx - γp)

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
surf = ax.plot_surface(
    xgrid * L, tgrid * T, u.reshape(xgrid.shape), cmap=cm.coolwarm
)
plt.title("u")
plt.xlabel("x")
plt.ylabel("t")
fig.colorbar(surf, shrink=0.5, aspect=10)
# plt.savefig(rundir / "upred_over_grid.pdf")
plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
surf = ax.plot_surface(
    xgrid * L, tgrid * T, γp.reshape(xgrid.shape), cmap=cm.coolwarm
)
plt.title("γp")
plt.xlabel("x")
plt.ylabel("t")
fig.colorbar(surf, shrink=0.5, aspect=10)
# plt.savefig(rundir / "γppred_over_grid.pdf")
plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
surf = ax.plot_surface(
    xgrid * L, tgrid * T, τ.reshape(xgrid.shape), cmap=cm.coolwarm
)
plt.title("τ")
plt.xlabel("x")
plt.ylabel("t")
# ax.set_zlim(0, 120)
fig.colorbar(surf, shrink=0.5, aspect=10)
# plt.savefig(rundir / "τpred_over_grid.pdf")
plt.show()

# %%
X_test = jnp.column_stack([ts, jnp.ones(n), jnp.full(n, μ / μscale)])
u, γp = jax.vmap(lambda x: state.apply_fn({"params": state.params}, x))(X_test)
u *= U
γp *= Γ
du = jax.vmap(jax.grad(lambda x: state.apply_fn({"params": state.params}, x)[0]))(X_test)
du_dx = du[:, 1] * U / L
τ = μ * (du_dx - γp)
γ = u / L

df = pd.read_csv("/home/ankit/OneDrive/PINN_Lele/flax_scripts3/fem_sols/anand_1d_fig_1a_curve1.csv")
fig = plt.figure()
plt.plot(df["x"], df["Curve1"], ls="--", label="DAL")
plt.plot(γ, τ, label="PIDL")
plt.xlabel("Strain γ")
plt.ylabel("Stress (MPa)")
plt.legend()
plt.show()

# %%
X_test = jnp.column_stack([jnp.ones(n), xs, jnp.full(n, μ / μscale)])
_, γp = jax.vmap(lambda x: state.apply_fn({"params": state.params}, x))(X_test)
γp *= Γ

df = pd.read_csv("/home/ankit/OneDrive/PINN_Lele/flax_scripts3/fem_sols/anand_1d_fig_1b_curve1.csv")
fig = plt.figure()
plt.plot(df["Curve1"], df["x"], label="DAL")
plt.plot(γp, xs, label="PIDL")
plt.xlim(left=0, right=0.15)
plt.legend()
plt.xlabel("Plastic strain γp")
plt.ylabel("y/h")
plt.show()

# %%
μ = 50e3
X_test = jnp.column_stack([ts, jnp.ones(n), jnp.full(n, μ / μscale)])
u, γp = jax.vmap(lambda x: state.apply_fn({"params": state.params}, x))(X_test)
u *= U
γp *= Γ
du = jax.vmap(jax.grad(lambda x: state.apply_fn({"params": state.params}, x)[0]))(X_test)
du_dx = du[:, 1] * U / L
τ50 = μ * (du_dx - γp)
γ50 = u / L

μ = 100e3
X_test = jnp.column_stack([ts, jnp.ones(n), jnp.full(n, μ / μscale)])
u, γp = jax.vmap(lambda x: state.apply_fn({"params": state.params}, x))(X_test)
u *= U
γp *= Γ
du = jax.vmap(jax.grad(lambda x: state.apply_fn({"params": state.params}, x)[0]))(X_test)
du_dx = du[:, 1] * U / L
τ100 = μ * (du_dx - γp)
γ100 = u / L

μ = 200e3
X_test = jnp.column_stack([ts, jnp.ones(n), jnp.full(n, μ / μscale)])
u, γp = jax.vmap(lambda x: state.apply_fn({"params": state.params}, x))(X_test)
u *= U
γp *= Γ
du = jax.vmap(jax.grad(lambda x: state.apply_fn({"params": state.params}, x)[0]))(X_test)
du_dx = du[:, 1] * U / L
τ200 = μ * (du_dx - γp)
γ200 = u / L

fig = plt.figure()
plt.plot(γ50, τ50, label=r"$\mu = 50e3$ MPa")
plt.plot(γ100, τ100, ls="--", label=r"$\mu = 100e3$ MPa")
plt.plot(γ200, τ200, ls=":", label=r"$\mu = 200e3$ MPa")
plt.xlabel("Strain γ")
plt.ylabel("Stress (MPa)")
plt.legend()
plt.show()
